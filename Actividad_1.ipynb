# %% [markdown]
# <a href="https://colab.research.google.com/github/J-Arturo-Rivas/CDSeptiembre2025/blob/Alim/Actividad_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Realizamos la actividad 1

# %%
edad=int(input("Ingresa tu edad"))
nombre= input("Ingresa tu nombre")
print("Hola", nombre)
print("Bienvenido al curso de Ciencia de Datos")
print("Tu edad es",edad)
# Out:
# Ingresa tu edad26
# Ingresa tu nombreArturo
# Hola Arturo
# Bienvenido al curso de Ciencia de Datos
# Tu edad es 26
