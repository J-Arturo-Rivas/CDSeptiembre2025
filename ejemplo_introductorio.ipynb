# %% [markdown]
# <a href="https://colab.research.google.com/github/J-Arturo-Rivas/CDSeptiembre2025/blob/main/ejemplo_introductorio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **INTRODUCCION AL LENGUAJE DE PROGRAMACION PYTHON**
#
# LOS COMANDOS BASICOS DE FUNCIONAMIENTO SON EL PRINT (ENVIAR UN MENSAJE) Y EL INPUT (RECIBIR UN MENSAJE)
#
# EJEMPLO

# %%
nombre=input("Ingrese su nombre")
print("Hola",nombre)
# Out:
# Ingrese su nombreAngel
# Hola Angel
